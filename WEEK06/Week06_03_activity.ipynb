# %% [markdown]
# <style>
# body h1:before, body h2:before, body h3:before, body h4:before, body h5:before, body h6:before {
#   content: "";
#   counter-increment: none;
# }
# </style>

# %% [raw]
# \setcounter{secnumdepth}{0}

# %% [markdown]
# # Week06.3 Team Activity
# Due Saturday May 13th, 2023 by 11:59pm - please upload PDF with photograph (either rendered or a separate file).  There is no expectation of completing this during class, in fact, I am trying to get you to practice working outside of class in teams in preparation for the final project.
#
# If you missed class – no credit for this activity, instead, I drop two unexcused absences from the Monday/Wednesday activities before deductions begin.
#
# - **Please identify your team & the names of your teammates.**
#
# - **Please insert a team photo somewhere in this notebook.  If you cannot get the to render correctly to PDF please upload a separate file of the photo**
#
# - **Please make certain that all of your teammates agree upon and understand the team answers. Thank you.**
#
# - **If you have already created your final team and/or selected your final dataset, you don't need to use the one shown here, you can use your own**

# %% [markdown]
# ## Assignment

# %% [markdown]
# As always, what is important is a team effort and that everyone on the team has an idea of how to program these things and also feels free to ask the team for more understanding.

# %% [markdown]
# Because we are in the process of forming final teams, if you are having trouble coming together as a team to complete an assignment like this one,  you should look for a different team for the next activity.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Please try reproducting as many of the following as you can as a team using the libraries imported above:

# %%
iris = pd.read_csv("https://raw.githubusercontent.com/lewv/SP23STAT21/main/WEEK02/iris.csv")
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2  \
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0       0.0
# ...

# %% [markdown]
# ![iris1.png](attachment:7b7c481c-c4d1-412f-be4c-9817e7204a4b.png)

# %% [markdown]
# <!-->![iris1](iris1.png)

# %% [markdown]
# ![iris2.png](attachment:74f6fcaf-6920-46da-acb6-060ec69789e7.png)

# %% [markdown]
# <!-->![iris2](iris2.png)

# %%
movies = pd.read_csv("http://www.stat.ucla.edu/~vlew/datasets/movies.csv")
movies
# Out:
#        Unnamed: 0                     title  year  length      budget  rating
# 0               1                         $  1971     121         NaN     6.4  \
# 1               2         $1000 a Touchdown  1939      71         NaN     6.0
# 2               3    $21 a Day Once a Month  1941       7         NaN     8.2
# 3               4                   $40,000  1996      70         NaN     8.2
# 4               5  $50,000 Climax Show, The  1975      71         NaN     3.4
# ...           ...                       ...   ...     ...         ...     ...
# 58783       58784                 tom thumb  1958      98         NaN     6.5
# 58784       58785               www.XXX.com  2003     105         NaN     1.1
# 58785       58786    www.hellssoapopera.com  1999     100         NaN     6.6
# 58786       58787                       xXx  2002     132  85000000.0     5.5
# 58787       58788   xXx: State of the Union  2005     101  87000000.0     3.9
#
# ...

# %% [markdown]
# ![movies_hexbin2.png](attachment:2012c67b-e98e-44b7-b1de-31dad2d2f07b.png)

# %% [markdown]
# <!-->![movies_hexbin2](movies_hexbin2.png)

# %% [markdown]
# This last one is totall optional and it requires a lot of work in pandas plus you will need to write your own function AND use some obscure methods in seaborn.  This is actually easy to do in ggplot in R but I had to ask ChatGPT how to do it using Seaborn.  It is a good ChatGPT exercise since you'll need to describe clearly it to ChatGPT to obtain assistance.

# %%
DIS = pd.read_csv("http://www.stat.ucla.edu/~vlew/datasets/DISNEY.csv", 
                  parse_dates = ["Date"])
# Extract year, Week and DOW
DIS['Year'] = DIS['Date'].dt.year
DIS['Week'] = DIS['Date'].dt.isocalendar().week
DIS['DOW'] = DIS['Date'].dt.dayofweek

# %% [markdown]
# ![disney_heatmap.png](attachment:fc1fe515-cc13-4dab-8d51-29d62511d24d.png)

# %% [markdown]
# <!-->![disney_heatmap](disney_heatmap.png)

# %% [markdown]
# ## What to submit for credit
#
# - Please upload the Jupyter Notebook (.ipynb) and PDF (preferred) OR .html (OK) to Bruin Learn with your team attempt.  Please make sure every team member understands the contents of the notebook.
#
# - This is due before 11:59pm Saturday 5/13/2023
