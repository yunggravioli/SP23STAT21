# %%
## Example Jupyter Notebook (.ipynb)

# %% [markdown]
# ## This is a Markdown cell
#
# You can write text that will be suitable for display even publication.
#
# No need for comment characters.
#
# You can put pretty much anything in here.
#
# ### Like code
#
# `print("whatever")`  (this won't run, it's highlighted code)
#
# ### Or some math
#
# $$    \binom{n}{k} = \frac{n!}{k!(n-k)!} $$
#
# ### and add external Images
#
# <img src="https://admission.ucla.edu/sites/default/files/slider-main-image/05-royce-2x.jpg" width="600" height="450"  />
#
# 😀

# %%
## This is a code cell

print("whatever")
# Out:
# whatever

# %% [markdown]
# ## This is another Markdown cell
#
# When you work with Jupyter notebooks you are simply moving back and forth between Markdown cells and Code cells.  You can also create graphics within a code cell (you'll learn all of this eventually):

# %%
import matplotlib.pyplot as plt

# create x and y data
x = list(range(1, 11))
y = list(range(2, 21, 2))

# generate a line plot
plt.plot(x, y, "r-")

# modify the default y tick marks
plt.yticks([0, 5, 10, 15, 20])

# label the x and y axis 
plt.xlabel("X Axis")
plt.ylabel("Y Axis")

# title the plot
plt.title("A Line Plot")

# show the plot
plt.show()

# %% [markdown]
# ## Remarks
#
# Getting a .ipynb file to output nicely is a bit tricky when external graphics are present.  Sometimes it might be better to put the graphic in a code cell, not Markdown:

# %%
## this is a code cell

from IPython import display
display.Image("https://admission.ucla.edu/sites/default/files/slider-main-image/05-royce-2x.jpg")

# %%
print('\U0001F609')
# Out:
# 😉
